# %%
import pandas as pd

Titanic=pd.read_csv("Titanic-Dataset.csv")

# %%
Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Titanic.fillna(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Titanic=Titanic.fillna(0)

# %%
Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#converting the Sex column (categorical) column to Numerical column
#.map is one of the functions used to convert a categorical column to numerical column
#pass in a dictionary into a map function

Titanic["Sex"].map({"male":0,"female":1})

Titanic["Sex"]=Titanic["Sex"].map({"male":0,"female":1})

# %%
#extract columns needed for prediction
#x is independent , Y is dependent

x=Titanic[["Pclass", "Sex", "Age", "SibSp", "Parch", "Fare"]]
y=Titanic["Survived"]

# %%
#split the x and y

from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.2, random_state=0)

# %%
# fit the model(train)

from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
a=model.predict(x_train)

# %%
# comparing x_train and prediction on x_train

xtrain_table= pd.DataFrame(x_train)

# %%
xtrain_table["Prediction"]= ""

# %%
xtrain_table
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare Prediction
# 140       3    1   0.0      0      2  15.2458
# 439       2    0  31.0      0      0  10.5000
# 817       2    0  31.0      1      1  37.0042
# 378       3    0  20.0      0      0   4.0125
# 491       3    0  21.0      0      0   7.2500
# ..      ...  ...   ...    ...    ...      ...        ...
# 835       1    1  39.0      1      1  83.1583
# 192       3    1  19.0      1      0   7.8542
# 629       3    0   0.0      0      0   7.7333
# 559       3    1  36.0      1      0  17.4000
# 684       2    0  60.0      1      1  39.0000
#
# [712 rows x 7 columns]

# %%
xtrain_table["Prediction"]=a

# %%
xtrain_table
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Prediction
# 140       3    1   0.0      0      2  15.2458           1
# 439       2    0  31.0      0      0  10.5000           0
# 817       2    0  31.0      1      1  37.0042           0
# 378       3    0  20.0      0      0   4.0125           0
# 491       3    0  21.0      0      0   7.2500           0
# ..      ...  ...   ...    ...    ...      ...         ...
# 835       1    1  39.0      1      1  83.1583           1
# 192       3    1  19.0      1      0   7.8542           1
# 629       3    0   0.0      0      0   7.7333           0
# 559       3    1  36.0      1      0  17.4000           1
# 684       2    0  60.0      1      1  39.0000           0
#
# [712 rows x 7 columns]

# %%
import warnings 
warnings.filterwarnings("ignore")
model.predict([[3,1,18,1,2,18.0]])
# Out:
# array([1], dtype=int64)

# %% [markdown]
# # Good Accuracy Score

# %%
#Evaluate result in logistic regression

from sklearn.metrics import accuracy_score, confusion_matrix

# %%
accuracy_score(y_train, a)
# Out:
# 0.7893258426966292

# %%
#Good accuracy score

#90% and above- very good
#70%-90%- Good
#60-70%- OK
#Below 60%- Poor

# %%
#confusion matrix is a table used to show accuracy of a logistic regression model
c=pd.crosstab(y_train, a)

# %%
import seaborn as sns

# %%
confusion_matrix=sns.heatmap(c, annot=True, yticklabels=["Survived","Not Survived"], xticklabels=["Survived","Not SUrvived"])
